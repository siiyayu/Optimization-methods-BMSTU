# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# зададим функцию f

f = lambda x, y: 6*x**2 - 4*x*y + 3*y**2 + 4*np.sqrt(5)*(x + 2*y) + 22
# зададим границ интервала
x0 = -2*np.sqrt(5)
y0 = 1
e = [0.01, 0.00001]

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.1.1

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
x_grid = np.linspace(-10, 10, 100)
y_grid = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x_grid, y_grid)
z = f(x,y)
ax.plot_surface(x, y, z)

# %%
def golden_section(f, a, b, e):
    phi = (1 + np.sqrt(5))/2
    x1 = b - (b - a)/phi
    x2 = a + (b - a)/phi
    f1 = f(x1)
    f2 = f(x2)
    it = 0
    it = 0
    while abs(b - a) > e: # 1e-17в бесокнечный цикл
        it += 1
        # it += 1
        # if it > 1000:
        #     break
        if f1 > f2:
            a = x1
            x1 = x2
            f1 = f2
            x2 = b - (x1 - a)
            f2 = f(x2)
        else:
            b = x2
            x2 = x1
            f2 = f1
            x1 = a + (b - x2)
            f1 = f(x1)
    return it, (a + b)/2

def dihotomia(g, a, b, eps):
    delta = eps/2 - eps*10**(-1)
    it = 0
    while abs(b - a) > eps:
        it += 1
        x = (a + b)/2
        g1 = g(x - delta)
        g2 = g(x + delta)
        if g1 < g2:
            b = x
        else:
            a = x
    return it, (a + b)/2

def gradient(v):
    x = v[0]
    y = v[1]
    dx_grad = 12*x - 4*y + 4*np.sqrt(5)
    dy_grad = -4*x + 6*y + 8*np.sqrt(5)
    return np.array([dx_grad, dy_grad])

# %%
def draw(f, points):
    levels = []
    for i in range(0, len(points)):
        levels.append(f(points[i][0], points[i][1]))
    levels.sort()
    X = np.arange(-10, 5, 0.25)
    Y = np.arange(-13.5, 5, 0.25)
    X, Y = np.meshgrid(X, Y)
    F = f(X, Y)
    fig, ax = plt.subplots(figsize=(8, 8))
    cs = ax.contour(X, Y, F, levels = levels)
    ax.clabel(cs)
    if len(points) == 2:
        plt.plot((points[0][0], points[1][0]),
                 (points[0][1], points[1][1]))
    else:
        for i in range(0, len(points) - 1):
            plt.plot((points[i][0], points[i + 1][0]),
                     (points[i][1], points[i + 1][1]))
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### Метод наискорейшего спуска

# %%
def fast_gd(f, x0, y0, eps):
    v = [x0, y0]
    points = []
    points.append(v)
    opt_it = 0
    while True:
        grad = gradient(v)
        it, s = golden_section(lambda s: f(v[0] - s*grad[0], v[1] - s*grad[1]), 0, 1, eps*1e-1)
        opt_it += it
        v_next = v - s*grad
        points.append(v_next)
        if abs(f(v_next[0], v_next[1]) - f(v[0], v[1])) <= eps:
            break
        v = v_next
    return opt_it, points, v_next

# %%
opt_it, points, v = fast_gd(f, x0, y0, e[0])
print("Num of its:", len(points) - 1)
print("Min", v)
print("1-d optimization num of its:", opt_it)
draw(f, points)
# Out:
# Num of its: 6
# Min [-2.23806749 -4.46686098]
# 1-d optimization num of its: 90

# %%
opt_it, points, v = fast_gd(f, x0, y0, e[1])
print("Num of its:", len(points) - 1)
print("Min", v)
print("1-d optimization num of its:", opt_it)
draw(f, points)
# Out:
# Num of its: 8
# Min [-2.23621516 -4.47177557]
# 1-d optimization num of its: 232

# %% [markdown]
# ### Метод сопряженных градиентов

# %%
def MSG(f, x0, y0, eps):
    points = []
    v = np.array([x0, y0])
    points.append(v)
    p = -gradient(v)
    # grad = -gradient(v) # Метод Полака-Рибьера
    grad_square = np.dot(p, p)
    opt_it = 0
    while True:
        it, alpha = golden_section(lambda s: f(v[0] + s*p[0], v[1] + s*p[1]),
                           0, 1, eps*1e-1)
        opt_it += it
        v = v + alpha*p
        points.append(v)
        new_grad = -gradient(v)
        new_grad_square = np.dot(new_grad, new_grad)
        beta = new_grad_square/grad_square # Метод Флетчера-Ривса
        # beta = -(new_grad_square - np.dot(new_grad, grad)) # Метод Полака-Рибьера
        p = new_grad + beta*p
        grad_square = new_grad_square
        # grad = new_grad # Метод Полака-Рибьера
        if grad_square < eps:
            break
    return opt_it, points, v

# %%
opt_it, points, v = MSG(f, x0, y0, e[0])
print("Num of its:", len(points) - 1)
print("Min", v)
print("1-d optimization num of its:", opt_it)
draw(f, points)
points
# Out:
# Num of its: 3
# Min [-2.23399041 -4.46818844]
# 1-d optimization num of its: 45
# [array([-4.47213595,  1.        ]),
#  array([-0.83126774, -2.12193403]),
#  array([-2.25172357, -4.45642632]),
#  array([-2.23399041, -4.46818844])]

# %%
opt_it, points, v = MSG(f, x0, y0, e[1])
print("Num of its:", len(points) - 1)
print("Min", v)
print("1-d optimization num of its:", opt_it)
draw(f, points)
points
# Out:
# Num of its: 2
# Min [-2.23605237 -4.47214601]
# 1-d optimization num of its: 58
# [array([-4.47213595,  1.        ]),
#  array([-0.83916958, -2.11515844]),
#  array([-2.23605237, -4.47214601])]

# %% [markdown]
# ### Метод Ньютона

# %%
def hesse_inv():
    return np.linalg.inv(np.array([[12, -4], [-4, 6]]))
def newton(f, x0, y0, eps):
    points = []
    v = np.array([x0, y0])
    points.append(v)
    while True:
        v_new = v - np.dot(hesse_inv(), gradient(v))
        if np.linalg.norm(v_new - v) < eps:
            break
        points.append(v_new)
        v = v_new
    return points, v_new

# %%
points, v = newton(f, x0, y0, e[0])
print("Num of its:", len(points) - 1)
print("Min", v)
draw(f, points)
# Out:
# Num of its: 1
# Min [-2.23606798 -4.47213595]

# %%
points, v = newton(f, x0, y0, e[1])
print("Num of its:", len(points) - 1)
print("Min", v)
draw(f, points)
# Out:
# Num of its: 1
# Min [-2.23606798 -4.47213595]

# %% [markdown]
# ### DFP

# %%
def draw_for_DFG(f, points):
    levels = []
    for i in range(0, len(points)):
        levels.append(f(points[i][0], points[i][1]))
    levels.sort()
    X = np.arange(-100, 100, 0.25)
    Y = np.arange(-100, 100, 0.25)
    X, Y = np.meshgrid(X, Y)
    F = f(X, Y)
    fig, ax = plt.subplots(figsize=(8, 8))
    cs = ax.contour(X, Y, F, levels = levels)
    ax.clabel(cs)
    if len(points) == 2:
        plt.plot((points[0][0], points[1][0]),
                 (points[0][1], points[1][1]))
    else:
        for i in range(0, len(points) - 1):
            plt.plot((points[i][0], points[i + 1][0]),
                     (points[i][1], points[i + 1][1]))
    plt.grid(True)
    plt.show()

# %%
def inner_prod(a, b):
    return a[0]*b[0] + a[1]*b[1]

def update_A(dv, dg, A):
    dv = np.array(dv).reshape(2, 1)
    dg = np.array(dg).reshape(2, 1)
    a = np.dot(np.dot(A, dg), np.dot(np.transpose(dg), A))
    b = inner_prod(np.dot(A, dg), dg)
    c = np.dot(dv, np.transpose(dv))
    d = inner_prod(dg, dv)
#     print(a, '\n\n', b, '\n\n', c, '\n\n', d)
    return np.array(A - a/b + c/d)
    
def DFP(f, x0, y0, eps):
    points = []
    v = np.array([x0, y0])
    points.append(v)
    A = np.eye(2)
    grad = gradient(v)
    while True:
        v_new = v - np.dot(A, grad)
        grad_new = gradient(v_new)
        if np.linalg.norm(v_new - v) < eps:
            break
        points.append(v_new)
        
        dv = v_new - v
        dg = grad_new - grad
        
        v = v_new
        grad = grad_new
        
        A = update_A(dv, dg, A)
    return points, v_new

# %%
points, v = DFP(f, x0, y0, e[0])
print("Num of its:", len(points) - 1)
print("Min", v)
draw(f, points)
draw_for_DFG(f, points)
points
# Out:
# Num of its: 4
# Min [-2.23606805 -4.47213591]
# [array([-4.47213595,  1.        ]),
#  array([ 44.24922359, -40.77708764]),
#  array([ -6.49780537, -11.66288498]),
#  array([ 9.06597135, 17.23640889]),
#  array([-2.23592043, -4.47223044])]

# %%
points, v = DFP(f, x0, y0, e[1])
print("Num of its:", len(points) - 1)
print("Min", v)
draw(f, points)
draw_for_DFG(f, points)
points
# Out:
# Num of its: 5
# Min [-2.23606798 -4.47213595]
# [array([-4.47213595,  1.        ]),
#  array([ 44.24922359, -40.77708764]),
#  array([ -6.49780537, -11.66288498]),
#  array([ 9.06597135, 17.23640889]),
#  array([-2.23592043, -4.47223044]),
#  array([-2.23606805, -4.47213591])]
